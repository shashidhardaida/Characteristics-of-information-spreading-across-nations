# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import zscore
import numpy as np

# %%
df = pd.read_excel('CountryVolumeFemaleDetect.xlsx')

# %%
df
# Out:
#        country  female_consistency  ...  Volume_20181001-20191001   SumVolume
# 0    Argentina            0.892285  ...                  119669.0    342594.0
# 1    Australia            0.902254  ...                   91504.0    296241.0
# 2      Austria            0.931055  ...                    2174.0      6514.0
# 3   Bangladesh            0.768966  ...                       NaN         NaN
# 4      Belgium            0.930885  ...                   16269.0     69050.0
# ..         ...                 ...  ...                       ...         ...
# 72         USA            0.911643  ...                 2816043.0  10937766.0
# 73   Venezuela            0.919814  ...                    8368.0     47957.0
# 74     Vietnam            0.550971  ...                     739.0      3748.0
# 75      Zambia            0.936620  ...                     388.0       619.0
# 76    Zimbabwe            0.927835  ...                    1402.0      1866.0
#
# [77 rows x 15 columns]

# %%
#Handling null values:

df.dropna(inplace=True)

# %%
                          ###### Scatter Plot between SumVolume and Population colored by Income level ######                          
 
fig = px.scatter(df, x="SumVolume", y="Population", color='Income.level', title='Scatter plot of SumVolume and Population colored by Income.level')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f06c3666-8059-4e61-b18f-0001700b5f44" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f06c3666-8059-4e61-b18f-0001700b5f44")) {
#                     Plotly.newPlot(
#                         'f06c3666-8059-4e61-b18f-0001700b5f44',
# ...

# %%
                          ########## Scatter plot between participation rate and female percentage #########

femalePercent20161001_20171001,femalePercent20171001_20181001,femalePercent20181001_20191001=[],[],[]
femalePercent20161001_20171001 = df['FemalePercent_201610-201710'].tolist()
femalePercent20171001_20181001 = df['FemalePercent_201710-201810'].tolist()
femalePercent20181001_20191001 = df['FemalePercent_201810-201910'].tolist()

# %%
participationRate_20161001_20171001=[]
participationRate_20161001_20171001 = (df['Volume_20161001-20071001']/df['Population']).tolist()
df1 = pd.DataFrame(zip(participationRate_20161001_20171001, femalePercent20161001_20171001), columns=['Participation Rate', 'Female Percentage'])
df1
# Out:
#     Participation Rate  Female Percentage
# 0         2.034360e-05           0.607595
# 1         3.999492e-05           0.659048
# 2         6.923428e-06           0.550000
# 3         1.230574e-05           0.537037
# 4         1.494294e-04           0.132233
# ..                 ...                ...
# 61        5.084157e-05           0.524272
# 62        1.657545e-04           0.749539
# 63        1.458839e-05           0.349693
# 64        2.964895e-06           0.053846
# 65        4.096831e-07           0.500000
#
# [66 rows x 2 columns]

# %%
fig = px.scatter(df1, x="Participation Rate", y="Female Percentage", title='Scatter plot of Participation rate and Female percentage for the peiod of 20161001-20171001')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c756ac69-f762-417f-a960-73238c471551" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c756ac69-f762-417f-a960-73238c471551")) {
#                     Plotly.newPlot(
#                         'c756ac69-f762-417f-a960-73238c471551',
# ...

# %%
participationRate_20171001_20181001=[]
participationRate_20171001_20181001 = (df['Volume_20171001-20181001']/df['Population']).tolist()
df2 = pd.DataFrame(zip(participationRate_20171001_20181001, femalePercent20171001_20181001), columns=['Participation Rate', 'Female Percentage'])
df2
# Out:
#     Participation Rate  Female Percentage
# 0             0.004958           0.655563
# 1             0.008083           0.578301
# 2             0.000478           0.457643
# 3             0.004562           0.592530
# 4             0.000726           0.551346
# ..                 ...                ...
# 61            0.000278           0.654709
# 62            0.024515           0.587839
# 63            0.001374           0.480409
# 64            0.000028           0.483607
# 65            0.000031           0.532374
#
# [66 rows x 2 columns]

# %%
fig = px.scatter(df2, x="Participation Rate", y="Female Percentage", title='Scatter plot of Participation rate and Female percentage for the peiod of 20171001-20181001')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7a9d68ac-6d56-4217-ac3e-e5ee096bae82" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7a9d68ac-6d56-4217-ac3e-e5ee096bae82")) {
#                     Plotly.newPlot(
#                         '7a9d68ac-6d56-4217-ac3e-e5ee096bae82',
# ...

# %%
participationRate_20181001_20191001=[]
participationRate_20181001_20191001 = (df['Volume_20181001-20191001']/df['Population']).tolist()
df3 = pd.DataFrame(zip(participationRate_20181001_20191001, femalePercent20181001_20191001), columns=['Participation Rate', 'Female Percentage'])
df3
# Out:
#     Participation Rate  Female Percentage
# 0             0.002672           0.557951
# 1             0.003631           0.525236
# 2             0.000243           0.445575
# 3             0.001410           0.496930
# 4             0.000171           0.489581
# ..                 ...                ...
# 61            0.000273           0.465909
# 62            0.008558           0.540059
# 63            0.000293           0.437296
# 64            0.000008           0.425806
# 65            0.000096           0.540881
#
# [66 rows x 2 columns]

# %%
fig = px.scatter(df3, x="Participation Rate", y="Female Percentage", title='Scatter plot of Participation rate and Female percentage for the peiod of 20181001-20191001')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="20b0c6f3-5661-4a2f-be17-143440dbd33b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("20b0c6f3-5661-4a2f-be17-143440dbd33b")) {
#                     Plotly.newPlot(
#                         '20b0c6f3-5661-4a2f-be17-143440dbd33b',
# ...

# %%
                ##### Scatter plot of GenderEqualityIndex and Female percentage colored by Income level #####

fig = px.scatter(df, x="GenderEqualityIndex", y="FemalePercent_201610-201710", color='Income.level', title='Scatter plot of Gender equality Index and Female percentage for the period 210610-201710')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7d4bb794-2c90-43a7-8bf0-6bbbd11dc717" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7d4bb794-2c90-43a7-8bf0-6bbbd11dc717")) {
#                     Plotly.newPlot(
#                         '7d4bb794-2c90-43a7-8bf0-6bbbd11dc717',
# ...

# %%
fig = px.scatter(df, x="GenderEqualityIndex", y="FemalePercent_201710-201810", color='Income.level', title='Scatter plot of Gender equality Index and Female percentage for the period 210710-201810')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2507781f-0ef8-4288-aedf-775b1c2174b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2507781f-0ef8-4288-aedf-775b1c2174b6")) {
#                     Plotly.newPlot(
#                         '2507781f-0ef8-4288-aedf-775b1c2174b6',
# ...

# %%
fig = px.scatter(df, x="GenderEqualityIndex", y="FemalePercent_201810-201910", color='Income.level', title='Scatter plot of Gender equality Index and Female percentage for the period 210810-201910')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cc893e79-f669-4f6b-a09f-b1ebf85e6e0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cc893e79-f669-4f6b-a09f-b1ebf85e6e0d")) {
#                     Plotly.newPlot(
#                         'cc893e79-f669-4f6b-a09f-b1ebf85e6e0d',
# ...
